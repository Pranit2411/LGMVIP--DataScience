# %% [markdown]
# ### **LGMVIP Data Science**
#
# ### **Beginner Level Task 4 : Image to Pencil Sketch with Python**
#
# Name - Pranit Dilip Menkar

# %%
from PIL import Image
from IPython.display import display
import cv2

# %% [markdown]
# # Loading the image

# %%
img = cv2.imread('Car.jpg', 1)
img = cv2.resize(img, (1900, 1000))
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
display(Image.fromarray(img))
# Out:
# <PIL.Image.Image image mode=RGB size=1900x1000 at 0x7FEE52F2F390>

# %% [markdown]
# # Converting image to grey scale

# %%
img_grey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
display(Image.fromarray(img_grey))
# Out:
# <PIL.Image.Image image mode=L size=1900x1000 at 0x7FEE6708D550>

# %% [markdown]
# # Inverting the image

# %%
img_inv = cv2.bitwise_not(img_grey)
display(Image.fromarray(img_inv))
# Out:
# <PIL.Image.Image image mode=L size=1900x1000 at 0x7FEE547A2550>

# %% [markdown]
# # Smoothing the image

# %%
img_smooth = cv2.GaussianBlur(img_inv, (5, 5), 0, 0)
display(Image.fromarray(img_smooth))
# Out:
# <PIL.Image.Image image mode=L size=1900x1000 at 0x7FEE54794CD0>

# %% [markdown]
# # Inverting the image to get final sketch

# %%
def dodge(img_grey, img_smooth):
  img_smooth_inv = 255 - img_smooth
  return cv2.divide(img_grey, img_smooth_inv, scale=256.0)

# %%
img_final = dodge(img_grey, img_smooth)
display(Image.fromarray(img_final))
# Out:
# <PIL.Image.Image image mode=L size=1900x1000 at 0x7FEE547A29D0>

# %% [markdown]
# # Comparing the Original Image with Pencil Sketch

# %%
display(Image.fromarray(img))
display(Image.fromarray(img_final))
# Out:
# <PIL.Image.Image image mode=RGB size=1900x1000 at 0x7FEE54783910>
# <PIL.Image.Image image mode=L size=1900x1000 at 0x7FEE54783810>
